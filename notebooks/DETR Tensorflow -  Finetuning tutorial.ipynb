# %% [markdown]
# # DETR : Finetuning tutorial
#
# In this tutorial we're gonna explore how to finetune DETR on the Hard hat Workers dataset: https://public.roboflow.com/object-detection/hard-hat-workers.
#
# <img src="../images/hardhatdataset.jpg"></img>
#
# To follow along and  run this notebook, the first things to do is to get the link to download the dataset on this page: https://public.roboflow.com/object-detection/hard-hat-workers
#
# - Click on "raw"
# - Then retrieve the download link from "Tensorflow Object Detection CSV"
# - Click on "show download code"
#
#
# <img src="../images/tutorials/download_hardhat_dataset.png"></img>
#
#
# Set the download link in the cell bellow
#
# <a id="cell1"></a>
# ## 1. Download the Hard Hat Workers Dataset
#
# ### Download and unzip files
#
# **Copy paste your download link bellow** to download the dataset into your home/data folder (feel free to set the path you want)

# %%
# !mkdir ~/data/hardhat/
# !wget -O ~/data/hardhat/hard-hat-workers-dataset.zip DOWNLOAD_LINK
# !unzip ~/data/hardhat/hard-hat-workers-dataset.zip -d ~/data/hardhat/
# !ls ~/data/hardhat/
# Out:
# mkdir: cannot create directory ‘/home/thibault/data/hardhat/’: File exists
# --2021-01-07 12:18:00--  https://public.roboflow.com/ds/t6dXY6HCPO?key=YPgumILnUk
# Resolving public.roboflow.com (public.roboflow.com)... 151.101.65.195, 151.101.1.195
# Connecting to public.roboflow.com (public.roboflow.com)|151.101.65.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/Ly2DeBzbwsemGd2ReHk4BFxy8683/TlE7G4GXJk3kU7ivmTPR/2/tensorflow.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=roboflow-platform%40appspot.gserviceaccount.com%2F20210107%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210107T111800Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# --2021-01-07 12:18:01--  https://storage.googleapis.com/roboflow-platform-exports/Ly2DeBzbwsemGd2ReHk4BFxy8683/TlE7G4GXJk3kU7ivmTPR/2/tensorflow.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=roboflow-platform%40appspot.gserviceaccount.com%2F20210107%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20210107T111800Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 216.58.198.208, 216.58.215.48, 172.217.19.240, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|216.58.198.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244369097 (233M) [application/zip]
# Saving to: ‘/home/thibault/data/hardhat/hard-hat-workers-dataset.zip’
#
# /home/thibault/data 100%[===================>] 233.05M  7.17MB/s    in 39s
#
# 2021-01-07 12:18:40 (6.01 MB/s) - ‘/home/thibault/data/hardhat/hard-hat-workers-dataset.zip’ saved [244369097/244369097]
#
# Archive:  /home/thibault/data/hardhat/hard-hat-workers-dataset.zip
# replace /home/thibault/data/hardhat/test/006637_jpg.rf.012e99d80844459254e586c7aa45adac.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
# hard-hat-workers-dataset.zip  README.roboflow.txt  train
# README.dataset.txt	      test

# %% [markdown]
# ## 2. Add detr_tf to your PYTHONPATH

# %%
import sys
# Set the path to the repository here
sys.path.append("../")
import detr_tf

# %% [markdown]
# ### If you're GPU is use for graphical display, you might need the following

# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print("Function Work")
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

#tf.compat.v1.disable_eager_execution()
# Out:
# Function Work

# %% [markdown]
# ## 3. Create your training config

# %%
from detr_tf.training_config import TrainingConfig
from os.path import expanduser
import os

class CustomConfig(TrainingConfig):

    def __init__(self):
        super().__init__()        
        # Dataset info
        self.datadir = os.path.join(expanduser("~"), "Desktop", "detr-tensorflow","detr_tf", "data","hardhat")
        # The model is trained using fixed size images.
        # The following is the desired target image size, but it can be change based on your
        # dataset
        self.image_size = (480, 720)
        # Batch size
        self.batch_size = 2
        # Using the target batch size , the training loop will agregate the gradient on 38 steps
        # before to update the weights
        self.target_batch = 8

config = CustomConfig()

# %% [markdown]
# ### Load the Hard Hat Workers Dataset
# Please, checkout the **How to load a dataset** notebook on the repository for more information

# %%
from detr_tf.data import load_tfcsv_dataset

# Load the dataset and exclude the person class (for some reason not all person are labeled on the training set)
# train_iterator, class_names = load_tfcsv_dataset("train", config.batch_size, config, augmentation=True, exclude=["person"])
# valid_iterator, class_names = load_tfcsv_dataset("test", config.batch_size, config, augmentation=False, exclude=["person"])

train_dt, class_names = load_tfcsv_dataset(config, config.batch_size, augmentation=True, exclude=["person"], ann_file="_annotations.csv", img_dir="train")
valid_dt, _ = load_tfcsv_dataset(config, 4, augmentation=False, exclude=["person"], ann_file="_annotations.csv", img_dir="test")
print("class_names", class_names)
# Out:
# class_names ['background', 'head', 'helmet']

# %% [markdown]
# ### Load the DETR model

# %%
from detr_tf.networks.detr import get_detr_model
# Load the pretrained DETR model with new heads at the top
# include_top: We do not include the last layers that predicts the bbox pos and class (include_top=False)
# nb_class: We add new layers on top of the model to predicts the bbox pos and class with three class (nb_class=3), background, helmet, face
# weights: Use the "detr" weight to init the model
detr = get_detr_model(config, include_top=False, nb_class=3, weights="detr")
detr.load_weights("weights/Helmet/detr-model.ckpt")
detr.summary()
# Out:
# Load weights from weights/detr\detr.ckpt
# Model: "detr_finetuning"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# detr (Functional)               (6, None, 100, 256)  41449152    input_2[0][0]
# __________________________________________________________________________________________________
# pos_layer (Sequential)          (6, None, 100, 4)    132612      detr[0][0]
# __________________________________________________________________________________________________
# cls_layer (Dense)               (6, None, 100, 3)    771         detr[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 100, 4)       0           pos_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 100, 3)       0           cls_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli (None, 100, 4)       0           pos_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 100, 3)       0           cls_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl (None, 100, 4)       0           pos_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli (None, 100, 3)       0           cls_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_12 (Sl (None, 100, 4)       0           pos_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_11 (Sl (None, 100, 3)       0           cls_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_14 (Sl (None, 100, 4)       0           pos_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_13 (Sl (None, 100, 3)       0           cls_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 100, 4)       0           pos_layer[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 100, 3)       0           cls_layer[0][0]
# ==================================================================================================
# Total params: 41,582,535
# Trainable params: 41,476,295
# Non-trainable params: 106,240
# __________________________________________________________________________________________________

# %% [markdown]
# #### First, change the config to train  only the layers on top of the transformers

# %%
# Train/finetune the transformers only
config.train_backbone = tf.Variable(False)
config.train_transformers = tf.Variable(False)
config.train_nlayers = tf.Variable(True)

# %% [markdown]
# #### Set the last layers learning rate

# %%
config.nlayers_lr = tf.Variable(1e-3)

# %%
from detr_tf.optimizers import setup_optimizers
# Setup the optimziers and the trainable variables
optimzers = setup_optimizers(detr, config)

# %% [markdown]
# ### Train the last layers on top of the transformer for one epoch
#
# - **ce** is the cross entropy loss of the layer that predicts the bbox class
# - **giou** and **l1** loss are the positional loss  of the layer that predicts the bbox pos (center_x, center_y, width, height)

# %%
from detr_tf import training
new_model = training.fit(detr, train_dt, optimzers, config, epoch_nb=0, class_names=class_names)
detr.save_weights("weights/Helmet/detr-model.ckpt")
# Out:
# Epoch: [0], 	 Step: [0], 	 ce: [2.17] 	 giou : [1.03] 	 l1 : [0.79] 	 time : [0.00]
# Epoch: [0], 	 Step: [100], 	 ce: [0.65] 	 giou : [0.67] 	 l1 : [0.13] 	 time : [54.92]
# Epoch: [0], 	 Step: [200], 	 ce: [0.50] 	 giou : [0.75] 	 l1 : [0.25] 	 time : [31.72]
# Epoch: [0], 	 Step: [300], 	 ce: [0.58] 	 giou : [0.82] 	 l1 : [0.12] 	 time : [31.72]
# Epoch: [0], 	 Step: [400], 	 ce: [0.72] 	 giou : [1.06] 	 l1 : [0.16] 	 time : [31.75]
# Epoch: [0], 	 Step: [500], 	 ce: [0.72] 	 giou : [0.66] 	 l1 : [0.13] 	 time : [31.75]
# Epoch: [0], 	 Step: [600], 	 ce: [0.66] 	 giou : [0.83] 	 l1 : [0.22] 	 time : [31.78]
# Epoch: [0], 	 Step: [700], 	 ce: [0.38] 	 giou : [0.61] 	 l1 : [0.12] 	 time : [31.80]
# Epoch: [0], 	 Step: [800], 	 ce: [0.42] 	 giou : [0.54] 	 l1 : [0.13] 	 time : [31.95]
# Epoch: [0], 	 Step: [900], 	 ce: [0.65] 	 giou : [0.60] 	 l1 : [0.07] 	 time : [31.87]
# Epoch: [0], 	 Step: [1000], 	 ce: [0.34] 	 giou : [0.68] 	 l1 : [0.18] 	 time : [31.85]
# Epoch: [0], 	 Step: [1100], 	 ce: [0.72] 	 giou : [0.57] 	 l1 : [0.11] 	 time : [31.78]
# Epoch: [0], 	 Step: [1200], 	 ce: [0.67] 	 giou : [0.84] 	 l1 : [0.09] 	 time : [31.86]
# Epoch: [0], 	 Step: [1300], 	 ce: [0.57] 	 giou : [0.57] 	 l1 : [0.06] 	 time : [31.89]
# Epoch: [0], 	 Step: [1400], 	 ce: [0.24] 	 giou : [0.62] 	 l1 : [0.09] 	 time : [31.83]
# Epoch: [0], 	 Step: [1500], 	 ce: [0.38] 	 giou : [0.54] 	 l1 : [0.08] 	 time : [31.81]
# Epoch: [0], 	 Step: [1600], 	 ce: [0.53] 	 giou : [0.59] 	 l1 : [0.19] 	 time : [31.91]
# Epoch: [0], 	 Step: [1700], 	 ce: [0.31] 	 giou : [0.35] 	 l1 : [0.08] 	 time : [31.92]
# Epoch: [0], 	 Step: [1800], 	 ce: [0.68] 	 giou : [0.75] 	 l1 : [0.06] 	 time : [31.89]
# Epoch: [0], 	 Step: [1900], 	 ce: [0.38] 	 giou : [0.77] 	 l1 : [0.14] 	 time : [31.88]
# Epoch: [0], 	 Step: [2000], 	 ce: [1.00] 	 giou : [0.57] 	 l1 : [0.08] 	 time : [31.83]
# Epoch: [0], 	 Step: [2100], 	 ce: [0.32] 	 giou : [0.57] 	 l1 : [0.07] 	 time : [31.80]
# Epoch: [0], 	 Step: [2200], 	 ce: [0.39] 	 giou : [0.57] 	 l1 : [0.09] 	 time : [31.91]
# Epoch: [0], 	 Step: [2300], 	 ce: [0.22] 	 giou : [0.68] 	 l1 : [0.07] 	 time : [31.91]
# Epoch: [0], 	 Step: [2400], 	 ce: [0.21] 	 giou : [0.43] 	 l1 : [0.10] 	 time : [31.87]
# Epoch: [0], 	 Step: [2500], 	 ce: [0.32] 	 giou : [0.34] 	 l1 : [0.07] 	 time : [31.95]
# Epoch: [0], 	 Step: [2600], 	 ce: [0.47] 	 giou : [0.75] 	 l1 : [0.07] 	 time : [31.89]
# Finish
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B1926A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B192BB0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B196CA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B196B50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B1C8160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B1C8670>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B1D2760>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B1D2C70>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B1DFD30>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B1DFBE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B2021F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B202700>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B20F7F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B20FD00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B21ADF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B21ACA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B22B400>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B22B910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B236A00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B236F10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B255E50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B255D00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000001CE7B266490>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <detr_tf.networks.custom_layers.FrozenBatchNorm2D object at 0x000001CE7B2669A0>, because it is not built.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3328d05167b7> in <module>
#       1 from detr_tf import training
#       2 new_model = training.fit(detr, train_dt, optimzers, config, epoch_nb=0, class_names=class_names)
# ----> 3 tf.saved_model.save(new_model, "/weights/Helmet")
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\saved_model\save.py in save(obj, export_dir, signatures, options)
#    1030   meta_graph_def = saved_model.meta_graphs.add()
#    1031
# -> 1032   _, exported_graph, object_saver, asset_info = _build_meta_graph(
#    1033       obj, signatures, options, meta_graph_def)
#    1034   saved_model.saved_model_schema_version = constants.SAVED_MODEL_SCHEMA_VERSION
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\saved_model\save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1196
#    1197   with save_context.save_context(options):
# -> 1198     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\saved_model\save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1130   checkpoint_graph_view = _AugmentedGraphView(obj)
#    1131   if signatures is None:
# -> 1132     signatures = signature_serialization.find_function_to_export(
#    1133         checkpoint_graph_view)
#    1134
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\saved_model\signature_serialization.py in find_function_to_export(saveable_view)
#      73   # If the user did not specify signatures, check the root object for a function
#      74   # that can be made into a signature.
# ---> 75   functions = saveable_view.list_functions(saveable_view.root)
#      76   signature = functions.get(DEFAULT_SIGNATURE_ATTR, None)
#      77   if signature is not None:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\saved_model\save.py in list_functions(self, obj, extra_functions)
#     148     obj_functions = self._functions.get(obj, None)
#     149     if obj_functions is None:
# --> 150       obj_functions = obj._list_functions_for_serialization(  # pylint: disable=protected-access
#     151           self._serialization_cache)
#     152       self._functions[obj] = obj_functions
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\engine\training.py in _list_functions_for_serialization(self, serialization_cache)
#    2610     self.test_function = None
#    2611     self.predict_function = None
# -> 2612     functions = super(
#    2613         Model, self)._list_functions_for_serialization(serialization_cache)
#    2614     self.train_function = train_function
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _list_functions_for_serialization(self, serialization_cache)
#    3084
#    3085   def _list_functions_for_serialization(self, serialization_cache):
# -> 3086     return (self._trackable_saved_model_saver
#    3087             .list_functions_for_serialization(serialization_cache))
#    3088
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\base_serialization.py in list_functions_for_serialization(self, serialization_cache)
#      92       return {}
#      93
# ---> 94     fns = self.functions_to_serialize(serialization_cache)
#      95
#      96     # The parent AutoTrackable class saves all user-defined tf.functions, and
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in functions_to_serialize(self, serialization_cache)
#      76
#      77   def functions_to_serialize(self, serialization_cache):
# ---> 78     return (self._get_serialized_attributes(
#      79         serialization_cache).functions_to_serialize)
#      80
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      92       return serialized_attr
#      93
# ---> 94     object_dict, function_dict = self._get_serialized_attributes_internal(
#      95         serialization_cache)
#      96
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      54     # the ones serialized by Layer.
#      55     objects, functions = (
# ---> 56         super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      57             serialization_cache))
#      58     functions['_default_save_signature'] = default_signature
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#     102     """Returns dictionary of serialized attributes."""
#     103     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# --> 104     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#     105     # Attribute validator requires that the default save signature is added to
#     106     # function dict, even if the value is None.
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     153   # Reset the losses of the layer and its children. The call function in each
#     154   # child layer is replaced with tf.functions.
# --> 155   original_fns = _replace_child_layer_functions(layer, serialization_cache)
#     156   original_losses = _reset_layer_losses(layer)
#     157
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in _replace_child_layer_functions(layer, serialization_cache)
#     271     if child_layer not in serialization_cache[constants.KERAS_CACHE_KEY]:
#     272       serialized_functions = (
# --> 273           child_layer._trackable_saved_model_saver._get_serialized_attributes(
#     274               serialization_cache).functions)
#     275     else:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      92       return serialized_attr
#      93
# ---> 94     object_dict, function_dict = self._get_serialized_attributes_internal(
#      95         serialization_cache)
#      96
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      54     # the ones serialized by Layer.
#      55     objects, functions = (
# ---> 56         super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      57             serialization_cache))
#      58     functions['_default_save_signature'] = default_signature
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#     102     """Returns dictionary of serialized attributes."""
#     103     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# --> 104     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#     105     # Attribute validator requires that the default save signature is added to
#     106     # function dict, even if the value is None.
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     153   # Reset the losses of the layer and its children. The call function in each
#     154   # child layer is replaced with tf.functions.
# --> 155   original_fns = _replace_child_layer_functions(layer, serialization_cache)
#     156   original_losses = _reset_layer_losses(layer)
#     157
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in _replace_child_layer_functions(layer, serialization_cache)
#     271     if child_layer not in serialization_cache[constants.KERAS_CACHE_KEY]:
#     272       serialized_functions = (
# --> 273           child_layer._trackable_saved_model_saver._get_serialized_attributes(
#     274               serialization_cache).functions)
#     275     else:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      92       return serialized_attr
#      93
# ---> 94     object_dict, function_dict = self._get_serialized_attributes_internal(
#      95         serialization_cache)
#      96
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      54     # the ones serialized by Layer.
#      55     objects, functions = (
# ---> 56         super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      57             serialization_cache))
#      58     functions['_default_save_signature'] = default_signature
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#     102     """Returns dictionary of serialized attributes."""
#     103     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# --> 104     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#     105     # Attribute validator requires that the default save signature is added to
#     106     # function dict, even if the value is None.
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     153   # Reset the losses of the layer and its children. The call function in each
#     154   # child layer is replaced with tf.functions.
# --> 155   original_fns = _replace_child_layer_functions(layer, serialization_cache)
#     156   original_losses = _reset_layer_losses(layer)
#     157
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in _replace_child_layer_functions(layer, serialization_cache)
#     271     if child_layer not in serialization_cache[constants.KERAS_CACHE_KEY]:
#     272       serialized_functions = (
# --> 273           child_layer._trackable_saved_model_saver._get_serialized_attributes(
#     274               serialization_cache).functions)
#     275     else:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      92       return serialized_attr
#      93
# ---> 94     object_dict, function_dict = self._get_serialized_attributes_internal(
#      95         serialization_cache)
#      96
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      54     # the ones serialized by Layer.
#      55     objects, functions = (
# ---> 56         super(ModelSavedModelSaver, self)._get_serialized_attributes_internal(
#      57             serialization_cache))
#      58     functions['_default_save_signature'] = default_signature
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\layer_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#     102     """Returns dictionary of serialized attributes."""
#     103     objects = save_impl.wrap_layer_objects(self.obj, serialization_cache)
# --> 104     functions = save_impl.wrap_layer_functions(self.obj, serialization_cache)
#     105     # Attribute validator requires that the default save signature is added to
#     106     # function dict, even if the value is None.
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in wrap_layer_functions(layer, serialization_cache)
#     161   # call with losses) are traced with the same inputs.
#     162   call_collection = LayerCallCollection(layer)
# --> 163   call_fn_with_losses = call_collection.add_function(
#     164       _wrap_call_and_conditional_losses(layer),
#     165       '{}_layer_call_and_return_conditional_losses'.format(layer.name))
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in add_function(self, call_fn, name)
#     503       # Manually add traces for layers that have keyword arguments and have
#     504       # a fully defined input signature.
# --> 505       self.add_trace(*self._input_signature)
#     506     return fn
#     507
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in add_trace(self, *args, **kwargs)
#     418             fn.get_concrete_function(*args, **kwargs)
#     419
# --> 420         trace_with_training(True)
#     421         trace_with_training(False)
#     422       else:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in trace_with_training(value, fn)
#     416           utils.set_training_arg(value, self._training_arg_index, args, kwargs)
#     417           with K.deprecated_internal_learning_phase_scope(value):
# --> 418             fn.get_concrete_function(*args, **kwargs)
#     419
#     420         trace_with_training(True)
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in get_concrete_function(self, *args, **kwargs)
#     548     if not self.call_collection.tracing:
#     549       self.call_collection.add_trace(*args, **kwargs)
# --> 550     return super(LayerCall, self).get_concrete_function(*args, **kwargs)
#     551
#     552
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in get_concrete_function(self, *args, **kwargs)
#    1297       ValueError: if this object has not yet been called on concrete values.
#    1298     """
# -> 1299     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1300     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1301     return concrete
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1203       if self._stateful_fn is None:
#    1204         initializers = []
# -> 1205         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1206         self._initialize_uninitialized_variables(initializers)
#    1207
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     723     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724     self._concrete_stateful_fn = (
# --> 725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726             *args, **kwds))
#     727
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in wrapper(*args, **kwargs)
#     525       with autocast_variable.enable_auto_cast_variables(
#     526           layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 527         ret = method(*args, **kwargs)
#     528     _restore_layer_losses(original_losses)
#     529     return ret
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     167       return wrapped_call(*args, **kwargs)
#     168
# --> 169     return control_flow_util.smart_cond(
#     170         training, lambda: replace_training_and_call(True),
#     171         lambda: replace_training_and_call(False))
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     112     return control_flow_ops.cond(
#     113         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 114   return smart_module.smart_cond(
#     115       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     116
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in <lambda>()
#     168
#     169     return control_flow_util.smart_cond(
# --> 170         training, lambda: replace_training_and_call(True),
#     171         lambda: replace_training_and_call(False))
#     172
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     165     def replace_training_and_call(training):
#     166       set_training_arg(training, training_arg_index, args, kwargs)
# --> 167       return wrapped_call(*args, **kwargs)
#     168
#     169     return control_flow_util.smart_cond(
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in call_and_return_conditional_losses(inputs, *args, **kwargs)
#     568   def call_and_return_conditional_losses(inputs, *args, **kwargs):
#     569     """Returns layer (call_output, conditional losses) tuple."""
# --> 570     call_output = layer_call(inputs, *args, **kwargs)
#     571     if version_utils.is_v1_layer_or_model(layer):
#     572       conditional_losses = layer.get_losses_for(inputs)
#
# ~\Desktop\detr-tensorflow\detr_tf\networks\transformer.py in call(self, target, memory, target_mask, memory_mask, target_key_padding_mask, memory_key_padding_mask, pos_encoding, query_encoding, training)
#     111
#     112         for layer in self.dec_layers:
# --> 113             x = layer(x, memory,
#     114                       target_mask=target_mask,
#     115                       memory_mask=memory_mask,
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in return_outputs_and_add_losses(*args, **kwargs)
#      71     inputs = args[inputs_arg_index]
#      72     args = args[inputs_arg_index + 1:]
# ---> 73     outputs, losses = fn(inputs, *args, **kwargs)
#      74     layer.add_loss(losses, inputs=inputs)
#      75
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     167       return wrapped_call(*args, **kwargs)
#     168
# --> 169     return control_flow_util.smart_cond(
#     170         training, lambda: replace_training_and_call(True),
#     171         lambda: replace_training_and_call(False))
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     112     return control_flow_ops.cond(
#     113         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 114   return smart_module.smart_cond(
#     115       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     116
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in <lambda>()
#     168
#     169     return control_flow_util.smart_cond(
# --> 170         training, lambda: replace_training_and_call(True),
#     171         lambda: replace_training_and_call(False))
#     172
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     165     def replace_training_and_call(training):
#     166       set_training_arg(training, training_arg_index, args, kwargs)
# --> 167       return wrapped_call(*args, **kwargs)
#     168
#     169     return control_flow_util.smart_cond(
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in __call__(self, *args, **kwargs)
#     542   def __call__(self, *args, **kwargs):
#     543     if not self.call_collection.tracing:
# --> 544       self.call_collection.add_trace(*args, **kwargs)
#     545     return super(LayerCall, self).__call__(*args, **kwargs)
#     546
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in add_trace(self, *args, **kwargs)
#     418             fn.get_concrete_function(*args, **kwargs)
#     419
# --> 420         trace_with_training(True)
#     421         trace_with_training(False)
#     422       else:
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in trace_with_training(value, fn)
#     416           utils.set_training_arg(value, self._training_arg_index, args, kwargs)
#     417           with K.deprecated_internal_learning_phase_scope(value):
# --> 418             fn.get_concrete_function(*args, **kwargs)
#     419
#     420         trace_with_training(True)
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in get_concrete_function(self, *args, **kwargs)
#     548     if not self.call_collection.tracing:
#     549       self.call_collection.add_trace(*args, **kwargs)
# --> 550     return super(LayerCall, self).get_concrete_function(*args, **kwargs)
#     551
#     552
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in get_concrete_function(self, *args, **kwargs)
#    1297       ValueError: if this object has not yet been called on concrete values.
#    1298     """
# -> 1299     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1300     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1301     return concrete
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1203       if self._stateful_fn is None:
#    1204         initializers = []
# -> 1205         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1206         self._initialize_uninitialized_variables(initializers)
#    1207
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     723     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724     self._concrete_stateful_fn = (
# --> 725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726             *args, **kwds))
#     727
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in wrapper(*args, **kwargs)
#     525       with autocast_variable.enable_auto_cast_variables(
#     526           layer._compute_dtype_object):  # pylint: disable=protected-access
# --> 527         ret = method(*args, **kwargs)
#     528     _restore_layer_losses(original_losses)
#     529     return ret
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in wrap_with_training_arg(*args, **kwargs)
#     167       return wrapped_call(*args, **kwargs)
#     168
# --> 169     return control_flow_util.smart_cond(
#     170         training, lambda: replace_training_and_call(True),
#     171         lambda: replace_training_and_call(False))
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\utils\control_flow_util.py in smart_cond(pred, true_fn, false_fn, name)
#     112     return control_flow_ops.cond(
#     113         pred, true_fn=true_fn, false_fn=false_fn, name=name)
# --> 114   return smart_module.smart_cond(
#     115       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#     116
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in <lambda>()
#     168
#     169     return control_flow_util.smart_cond(
# --> 170         training, lambda: replace_training_and_call(True),
#     171         lambda: replace_training_and_call(False))
#     172
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\utils.py in replace_training_and_call(training)
#     165     def replace_training_and_call(training):
#     166       set_training_arg(training, training_arg_index, args, kwargs)
# --> 167       return wrapped_call(*args, **kwargs)
#     168
#     169     return control_flow_util.smart_cond(
#
# ~\anaconda3\envs\build-tf\lib\site-packages\tensorflow\python\keras\saving\saved_model\save_impl.py in call_and_return_conditional_losses(inputs, *args, **kwargs)
#     568   def call_and_return_conditional_losses(inputs, *args, **kwargs):
#     569     """Returns layer (call_output, conditional losses) tuple."""
# --> 570     call_output = layer_call(inputs, *args, **kwargs)
#     571     if version_utils.is_v1_layer_or_model(layer):
#     572       conditional_losses = layer.get_losses_for(inputs)
#
# ~\Desktop\detr-tensorflow\detr_tf\networks\transformer.py in call(self, target, memory, target_mask, memory_mask, target_key_padding_mask, memory_key_padding_mask, pos_encoding, query_encoding, training)
#     217
#     218         query_tgt = target + query_encoding
# --> 219         key_mem = memory + pos_encoding
#     220
#     221         attn_target2 = self.multihead_attn((query_tgt, key_mem, memory), attn_mask=memory_mask,
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
detr.save_weights("weights/Helmet/detr-model.ckpt")

# %% [markdown]
# ### Let's check the training results after one epoch

# %%
from detr_tf.inference import get_model_inference, numpy_bbox_to_image
import matplotlib.pyplot as plt
import numpy as np


for valid_images, target_bbox, target_class in valid_dt:
    
    m_outputs = detr(valid_images, training=False)
    predicted_bbox, predicted_labels, predicted_scores = get_model_inference(m_outputs, config.background_class, bbox_format="xy_center")

    result = numpy_bbox_to_image(
        np.array(valid_images[0]),
        np.array(predicted_bbox),
        np.array(predicted_labels),
        scores=np.array(predicted_scores),
        class_name=class_names, 
        config=config
    )
    plt.imshow(result)
    plt.show()
    break

# %% [markdown]
# ## Now to get better results we can train the new layers along with the transformers and let the backbone freeze

# %%
# After the first epoch, we finetune the transformers and the new layers
config.train_transformers.assign(True)
config.transformers_lr.assign(1e-4)
config.nlayers_lr.assign(1e-3)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=float32, numpy=0.001>

# %%
for epoch in range(1, 6):
    training.fit(detr,  train_dt, optimzers, config, epoch_nb=epoch, class_names=class_names)
# Out:
# Epoch: [1], 	 Step: [0], 	 ce: [0.39] 	 giou : [0.69] 	 l1 : [0.12] 	 time : [0.00]
# Epoch: [1], 	 Step: [100], 	 ce: [0.41] 	 giou : [0.64] 	 l1 : [0.11] 	 time : [62.26]
# Epoch: [1], 	 Step: [200], 	 ce: [0.30] 	 giou : [0.58] 	 l1 : [0.15] 	 time : [35.60]
# Epoch: [1], 	 Step: [300], 	 ce: [0.46] 	 giou : [0.57] 	 l1 : [0.07] 	 time : [35.63]
# Epoch: [1], 	 Step: [400], 	 ce: [0.45] 	 giou : [0.77] 	 l1 : [0.07] 	 time : [35.69]
# Epoch: [1], 	 Step: [500], 	 ce: [0.59] 	 giou : [0.52] 	 l1 : [0.05] 	 time : [35.75]
# Epoch: [1], 	 Step: [600], 	 ce: [0.71] 	 giou : [0.54] 	 l1 : [0.10] 	 time : [35.73]
# Epoch: [1], 	 Step: [700], 	 ce: [0.48] 	 giou : [0.55] 	 l1 : [0.05] 	 time : [35.78]
# Epoch: [1], 	 Step: [800], 	 ce: [0.52] 	 giou : [0.49] 	 l1 : [0.06] 	 time : [35.72]
# Epoch: [1], 	 Step: [900], 	 ce: [0.48] 	 giou : [0.55] 	 l1 : [0.04] 	 time : [35.79]
# Epoch: [1], 	 Step: [1000], 	 ce: [0.33] 	 giou : [0.41] 	 l1 : [0.05] 	 time : [35.69]
# Epoch: [1], 	 Step: [1100], 	 ce: [0.27] 	 giou : [0.31] 	 l1 : [0.07] 	 time : [35.73]
# Epoch: [1], 	 Step: [1200], 	 ce: [0.79] 	 giou : [0.45] 	 l1 : [0.06] 	 time : [35.78]
# Epoch: [1], 	 Step: [1300], 	 ce: [0.31] 	 giou : [0.24] 	 l1 : [0.03] 	 time : [35.75]
# Epoch: [1], 	 Step: [1400], 	 ce: [0.59] 	 giou : [0.59] 	 l1 : [0.04] 	 time : [35.75]
# Epoch: [1], 	 Step: [1500], 	 ce: [0.55] 	 giou : [0.48] 	 l1 : [0.03] 	 time : [35.71]
# Epoch: [1], 	 Step: [1600], 	 ce: [0.33] 	 giou : [0.33] 	 l1 : [0.05] 	 time : [35.72]
# Epoch: [1], 	 Step: [1700], 	 ce: [0.20] 	 giou : [0.29] 	 l1 : [0.04] 	 time : [35.64]
# Epoch: [1], 	 Step: [1800], 	 ce: [0.30] 	 giou : [0.23] 	 l1 : [0.06] 	 time : [35.67]
# Epoch: [1], 	 Step: [1900], 	 ce: [0.29] 	 giou : [0.39] 	 l1 : [0.07] 	 time : [35.75]
# Epoch: [1], 	 Step: [2000], 	 ce: [0.14] 	 giou : [0.43] 	 l1 : [0.06] 	 time : [35.68]
# Epoch: [1], 	 Step: [2100], 	 ce: [0.24] 	 giou : [0.58] 	 l1 : [0.07] 	 time : [35.68]
# Epoch: [1], 	 Step: [2200], 	 ce: [0.83] 	 giou : [0.40] 	 l1 : [0.05] 	 time : [35.65]
# Epoch: [1], 	 Step: [2300], 	 ce: [0.51] 	 giou : [0.36] 	 l1 : [0.04] 	 time : [35.63]
# Epoch: [1], 	 Step: [2400], 	 ce: [0.36] 	 giou : [0.24] 	 l1 : [0.09] 	 time : [35.67]
# Epoch: [1], 	 Step: [2500], 	 ce: [0.38] 	 giou : [0.31] 	 l1 : [0.03] 	 time : [35.69]
# Epoch: [1], 	 Step: [2600], 	 ce: [0.10] 	 giou : [0.33] 	 l1 : [0.14] 	 time : [35.74]
# Finish
# Epoch: [2], 	 Step: [0], 	 ce: [0.26] 	 giou : [0.46] 	 l1 : [0.05] 	 time : [0.00]
# Epoch: [2], 	 Step: [100], 	 ce: [0.40] 	 giou : [0.33] 	 l1 : [0.04] 	 time : [35.72]
# Epoch: [2], 	 Step: [200], 	 ce: [0.22] 	 giou : [0.30] 	 l1 : [0.05] 	 time : [35.70]
# Epoch: [2], 	 Step: [300], 	 ce: [0.19] 	 giou : [0.41] 	 l1 : [0.04] 	 time : [35.73]
# Epoch: [2], 	 Step: [400], 	 ce: [0.48] 	 giou : [0.41] 	 l1 : [0.04] 	 time : [35.75]
# Epoch: [2], 	 Step: [500], 	 ce: [0.33] 	 giou : [0.57] 	 l1 : [0.04] 	 time : [35.65]
# Epoch: [2], 	 Step: [600], 	 ce: [0.31] 	 giou : [0.28] 	 l1 : [0.04] 	 time : [35.98]
# Epoch: [2], 	 Step: [700], 	 ce: [0.37] 	 giou : [0.56] 	 l1 : [0.04] 	 time : [35.70]
# Epoch: [2], 	 Step: [800], 	 ce: [0.27] 	 giou : [0.32] 	 l1 : [0.03] 	 time : [35.66]
# Epoch: [2], 	 Step: [900], 	 ce: [0.12] 	 giou : [0.27] 	 l1 : [0.04] 	 time : [35.63]
# Epoch: [2], 	 Step: [1000], 	 ce: [0.03] 	 giou : [0.19] 	 l1 : [0.09] 	 time : [35.67]
# Epoch: [2], 	 Step: [1100], 	 ce: [0.32] 	 giou : [0.48] 	 l1 : [0.09] 	 time : [35.81]
# Epoch: [2], 	 Step: [1200], 	 ce: [0.47] 	 giou : [0.37] 	 l1 : [0.04] 	 time : [35.68]
# Epoch: [2], 	 Step: [1300], 	 ce: [0.12] 	 giou : [0.24] 	 l1 : [0.04] 	 time : [35.72]
# Epoch: [2], 	 Step: [1400], 	 ce: [0.01] 	 giou : [0.40] 	 l1 : [0.04] 	 time : [35.66]
# Epoch: [2], 	 Step: [1500], 	 ce: [0.25] 	 giou : [0.47] 	 l1 : [0.04] 	 time : [35.65]
# Epoch: [2], 	 Step: [1600], 	 ce: [0.20] 	 giou : [0.29] 	 l1 : [0.05] 	 time : [35.73]
# Epoch: [2], 	 Step: [1700], 	 ce: [0.03] 	 giou : [0.13] 	 l1 : [0.03] 	 time : [35.75]
# Epoch: [2], 	 Step: [1800], 	 ce: [0.43] 	 giou : [0.47] 	 l1 : [0.03] 	 time : [35.70]
# Epoch: [2], 	 Step: [1900], 	 ce: [0.09] 	 giou : [0.43] 	 l1 : [0.05] 	 time : [35.61]
# Epoch: [2], 	 Step: [2000], 	 ce: [0.32] 	 giou : [0.43] 	 l1 : [0.03] 	 time : [35.69]
# Epoch: [2], 	 Step: [2100], 	 ce: [0.84] 	 giou : [0.28] 	 l1 : [0.03] 	 time : [35.64]
# Epoch: [2], 	 Step: [2200], 	 ce: [0.31] 	 giou : [0.31] 	 l1 : [0.03] 	 time : [35.60]
# Epoch: [2], 	 Step: [2300], 	 ce: [0.28] 	 giou : [0.33] 	 l1 : [0.06] 	 time : [35.67]
# Epoch: [2], 	 Step: [2400], 	 ce: [0.04] 	 giou : [0.26] 	 l1 : [0.07] 	 time : [35.65]
# Epoch: [2], 	 Step: [2500], 	 ce: [0.06] 	 giou : [0.30] 	 l1 : [0.06] 	 time : [35.69]
# Epoch: [2], 	 Step: [2600], 	 ce: [0.35] 	 giou : [0.48] 	 l1 : [0.03] 	 time : [35.76]
# Finish
# Epoch: [3], 	 Step: [0], 	 ce: [0.26] 	 giou : [0.33] 	 l1 : [0.05] 	 time : [0.00]
# Epoch: [3], 	 Step: [100], 	 ce: [0.07] 	 giou : [0.28] 	 l1 : [0.03] 	 time : [35.63]
# Epoch: [3], 	 Step: [200], 	 ce: [0.08] 	 giou : [0.28] 	 l1 : [0.06] 	 time : [35.62]
# Epoch: [3], 	 Step: [300], 	 ce: [0.34] 	 giou : [0.28] 	 l1 : [0.04] 	 time : [35.65]
# Epoch: [3], 	 Step: [400], 	 ce: [0.10] 	 giou : [0.38] 	 l1 : [0.04] 	 time : [35.61]
# Epoch: [3], 	 Step: [500], 	 ce: [0.06] 	 giou : [0.26] 	 l1 : [0.04] 	 time : [35.70]
# Epoch: [3], 	 Step: [600], 	 ce: [0.24] 	 giou : [0.37] 	 l1 : [0.04] 	 time : [35.71]
# Epoch: [3], 	 Step: [700], 	 ce: [0.06] 	 giou : [0.23] 	 l1 : [0.04] 	 time : [35.67]
# Epoch: [3], 	 Step: [800], 	 ce: [0.03] 	 giou : [0.36] 	 l1 : [0.04] 	 time : [35.67]
# Epoch: [3], 	 Step: [900], 	 ce: [0.11] 	 giou : [0.46] 	 l1 : [0.03] 	 time : [35.71]
# Epoch: [3], 	 Step: [1000], 	 ce: [0.25] 	 giou : [0.21] 	 l1 : [0.03] 	 time : [35.65]
# Epoch: [3], 	 Step: [1100], 	 ce: [0.28] 	 giou : [0.38] 	 l1 : [0.04] 	 time : [35.68]
# Epoch: [3], 	 Step: [1200], 	 ce: [0.38] 	 giou : [0.44] 	 l1 : [0.03] 	 time : [35.60]
# Epoch: [3], 	 Step: [1300], 	 ce: [0.14] 	 giou : [0.35] 	 l1 : [0.04] 	 time : [35.63]
# Epoch: [3], 	 Step: [1400], 	 ce: [0.20] 	 giou : [0.28] 	 l1 : [0.03] 	 time : [35.67]
# Epoch: [3], 	 Step: [1500], 	 ce: [0.01] 	 giou : [0.17] 	 l1 : [0.05] 	 time : [35.70]
# Epoch: [3], 	 Step: [1600], 	 ce: [0.13] 	 giou : [0.32] 	 l1 : [0.12] 	 time : [35.70]
# Epoch: [3], 	 Step: [1700], 	 ce: [0.14] 	 giou : [0.27] 	 l1 : [0.05] 	 time : [35.67]
# Epoch: [3], 	 Step: [1800], 	 ce: [0.27] 	 giou : [0.35] 	 l1 : [0.04] 	 time : [35.58]
# Epoch: [3], 	 Step: [1900], 	 ce: [0.02] 	 giou : [0.19] 	 l1 : [0.04] 	 time : [35.66]
# Epoch: [3], 	 Step: [2000], 	 ce: [0.08] 	 giou : [0.47] 	 l1 : [0.03] 	 time : [35.70]
# Epoch: [3], 	 Step: [2100], 	 ce: [0.33] 	 giou : [0.43] 	 l1 : [0.03] 	 time : [35.68]
# Epoch: [3], 	 Step: [2200], 	 ce: [0.01] 	 giou : [0.32] 	 l1 : [0.07] 	 time : [35.69]
# Epoch: [3], 	 Step: [2300], 	 ce: [0.15] 	 giou : [0.32] 	 l1 : [0.04] 	 time : [35.63]
# Epoch: [3], 	 Step: [2400], 	 ce: [0.16] 	 giou : [0.32] 	 l1 : [0.04] 	 time : [35.62]
# Epoch: [3], 	 Step: [2500], 	 ce: [0.03] 	 giou : [0.30] 	 l1 : [0.05] 	 time : [35.68]
# Epoch: [3], 	 Step: [2600], 	 ce: [0.15] 	 giou : [0.30] 	 l1 : [0.05] 	 time : [35.64]
# Finish
# Epoch: [4], 	 Step: [0], 	 ce: [0.22] 	 giou : [0.18] 	 l1 : [0.05] 	 time : [0.00]
# Epoch: [4], 	 Step: [100], 	 ce: [0.18] 	 giou : [0.37] 	 l1 : [0.05] 	 time : [35.69]
# Epoch: [4], 	 Step: [200], 	 ce: [0.04] 	 giou : [0.28] 	 l1 : [0.05] 	 time : [35.60]
# Epoch: [4], 	 Step: [300], 	 ce: [0.06] 	 giou : [0.44] 	 l1 : [0.04] 	 time : [35.63]
# Epoch: [4], 	 Step: [400], 	 ce: [0.10] 	 giou : [0.45] 	 l1 : [0.05] 	 time : [35.65]
# Epoch: [4], 	 Step: [500], 	 ce: [0.02] 	 giou : [0.40] 	 l1 : [0.06] 	 time : [35.66]
# Epoch: [4], 	 Step: [600], 	 ce: [0.10] 	 giou : [0.34] 	 l1 : [0.04] 	 time : [35.66]
# Epoch: [4], 	 Step: [700], 	 ce: [0.02] 	 giou : [0.18] 	 l1 : [0.04] 	 time : [35.68]
# Epoch: [4], 	 Step: [800], 	 ce: [0.02] 	 giou : [0.38] 	 l1 : [0.03] 	 time : [35.55]
# Epoch: [4], 	 Step: [900], 	 ce: [0.26] 	 giou : [0.35] 	 l1 : [0.03] 	 time : [35.73]
# Epoch: [4], 	 Step: [1000], 	 ce: [0.01] 	 giou : [0.44] 	 l1 : [0.07] 	 time : [35.62]
# Epoch: [4], 	 Step: [1100], 	 ce: [0.40] 	 giou : [0.45] 	 l1 : [0.04] 	 time : [35.68]
# Epoch: [4], 	 Step: [1200], 	 ce: [0.40] 	 giou : [0.36] 	 l1 : [0.03] 	 time : [35.67]
# Epoch: [4], 	 Step: [1300], 	 ce: [0.02] 	 giou : [0.45] 	 l1 : [0.06] 	 time : [35.62]
# Epoch: [4], 	 Step: [1400], 	 ce: [0.01] 	 giou : [0.24] 	 l1 : [0.02] 	 time : [37.40]
# Epoch: [4], 	 Step: [1500], 	 ce: [0.38] 	 giou : [0.40] 	 l1 : [0.03] 	 time : [35.63]
# Epoch: [4], 	 Step: [1600], 	 ce: [0.15] 	 giou : [0.23] 	 l1 : [0.05] 	 time : [35.65]
# Epoch: [4], 	 Step: [1700], 	 ce: [0.01] 	 giou : [0.23] 	 l1 : [0.05] 	 time : [35.66]
# Epoch: [4], 	 Step: [1800], 	 ce: [0.24] 	 giou : [0.49] 	 l1 : [0.04] 	 time : [35.66]
# Epoch: [4], 	 Step: [1900], 	 ce: [0.03] 	 giou : [0.32] 	 l1 : [0.05] 	 time : [35.62]
# Epoch: [4], 	 Step: [2000], 	 ce: [0.06] 	 giou : [0.35] 	 l1 : [0.03] 	 time : [35.54]
# Epoch: [4], 	 Step: [2100], 	 ce: [0.34] 	 giou : [0.37] 	 l1 : [0.04] 	 time : [35.55]
# Epoch: [4], 	 Step: [2200], 	 ce: [0.02] 	 giou : [0.44] 	 l1 : [0.06] 	 time : [35.52]
# Epoch: [4], 	 Step: [2300], 	 ce: [0.01] 	 giou : [0.30] 	 l1 : [0.05] 	 time : [35.67]
# Epoch: [4], 	 Step: [2400], 	 ce: [0.02] 	 giou : [0.32] 	 l1 : [0.04] 	 time : [35.71]
# Epoch: [4], 	 Step: [2500], 	 ce: [0.01] 	 giou : [0.24] 	 l1 : [0.05] 	 time : [35.60]
# Epoch: [4], 	 Step: [2600], 	 ce: [0.11] 	 giou : [0.31] 	 l1 : [0.02] 	 time : [35.62]
# Finish
# Epoch: [5], 	 Step: [0], 	 ce: [0.10] 	 giou : [0.30] 	 l1 : [0.04] 	 time : [0.00]
# Epoch: [5], 	 Step: [100], 	 ce: [0.02] 	 giou : [0.31] 	 l1 : [0.03] 	 time : [35.72]
# Epoch: [5], 	 Step: [200], 	 ce: [0.02] 	 giou : [0.22] 	 l1 : [0.04] 	 time : [35.61]
# Epoch: [5], 	 Step: [300], 	 ce: [0.15] 	 giou : [0.23] 	 l1 : [0.03] 	 time : [35.63]
# Epoch: [5], 	 Step: [400], 	 ce: [0.16] 	 giou : [0.39] 	 l1 : [0.04] 	 time : [35.66]
# Epoch: [5], 	 Step: [500], 	 ce: [0.01] 	 giou : [0.27] 	 l1 : [0.04] 	 time : [35.64]
# Epoch: [5], 	 Step: [600], 	 ce: [0.20] 	 giou : [0.29] 	 l1 : [0.03] 	 time : [35.65]
# Epoch: [5], 	 Step: [700], 	 ce: [0.02] 	 giou : [0.19] 	 l1 : [0.03] 	 time : [35.55]
# Epoch: [5], 	 Step: [800], 	 ce: [0.01] 	 giou : [0.31] 	 l1 : [0.04] 	 time : [35.59]
# Epoch: [5], 	 Step: [900], 	 ce: [0.12] 	 giou : [0.26] 	 l1 : [0.02] 	 time : [35.59]
# Epoch: [5], 	 Step: [1000], 	 ce: [0.01] 	 giou : [0.35] 	 l1 : [0.05] 	 time : [35.60]
# Epoch: [5], 	 Step: [1100], 	 ce: [0.25] 	 giou : [0.28] 	 l1 : [0.04] 	 time : [35.61]
# Epoch: [5], 	 Step: [1200], 	 ce: [0.38] 	 giou : [0.40] 	 l1 : [0.03] 	 time : [36.07]
# Epoch: [5], 	 Step: [1300], 	 ce: [0.33] 	 giou : [0.47] 	 l1 : [0.04] 	 time : [36.09]
# Epoch: [5], 	 Step: [1400], 	 ce: [0.10] 	 giou : [0.40] 	 l1 : [0.03] 	 time : [36.05]
# Epoch: [5], 	 Step: [1500], 	 ce: [0.07] 	 giou : [0.41] 	 l1 : [0.04] 	 time : [36.04]
# Epoch: [5], 	 Step: [1600], 	 ce: [0.10] 	 giou : [0.27] 	 l1 : [0.12] 	 time : [35.78]
# Epoch: [5], 	 Step: [1700], 	 ce: [0.02] 	 giou : [0.21] 	 l1 : [0.06] 	 time : [35.55]
# Epoch: [5], 	 Step: [1800], 	 ce: [0.49] 	 giou : [0.34] 	 l1 : [0.03] 	 time : [35.66]
# Epoch: [5], 	 Step: [1900], 	 ce: [0.01] 	 giou : [0.23] 	 l1 : [0.04] 	 time : [35.68]
# Epoch: [5], 	 Step: [2000], 	 ce: [0.05] 	 giou : [0.35] 	 l1 : [0.03] 	 time : [35.69]
# Epoch: [5], 	 Step: [2100], 	 ce: [0.35] 	 giou : [0.39] 	 l1 : [0.06] 	 time : [35.66]
# Epoch: [5], 	 Step: [2200], 	 ce: [0.09] 	 giou : [0.38] 	 l1 : [0.04] 	 time : [35.63]
# Epoch: [5], 	 Step: [2300], 	 ce: [0.03] 	 giou : [0.26] 	 l1 : [0.06] 	 time : [35.72]
# Epoch: [5], 	 Step: [2400], 	 ce: [0.09] 	 giou : [0.23] 	 l1 : [0.03] 	 time : [35.65]
# Epoch: [5], 	 Step: [2500], 	 ce: [0.01] 	 giou : [0.16] 	 l1 : [0.03] 	 time : [35.65]
# Epoch: [5], 	 Step: [2600], 	 ce: [0.08] 	 giou : [0.38] 	 l1 : [0.03] 	 time : [35.71]
# Finish

# %%
detr.save_weights("weights/Helmet/detr-model.ckpt")

# %%
from detr_tf.inference import get_model_inference, numpy_bbox_to_image
import matplotlib.pyplot as plt
import numpy as np



for valid_images, target_bbox, target_class in valid_dt:
    
    m_outputs = detr(valid_images, training=False)
    predicted_bbox, predicted_labels, predicted_scores = get_model_inference(m_outputs, config.background_class, bbox_format="xy_center")

    result = numpy_bbox_to_image(
        np.array(valid_images[0]),
        np.array(predicted_bbox),
        np.array(predicted_labels),
        scores=np.array(predicted_scores),
        class_name=class_names, 
        config=config
    )
    plt.imshow(result)
    plt.show()
    break
